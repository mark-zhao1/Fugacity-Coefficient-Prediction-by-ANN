# %% [markdown]
# # Objective
#
# Plot and compare phase split compositions of ANN and EOS along a mixing line at constant T, P.
#
# Now that ANN models for nC4 and nC10 have been tried to compute phase split calculations, its time to compare them.
#
# 1) Store ANN phase split compositions of liquid and vapor
# 2) Store EOS phase split compositions of liquid and vapor
# 3) Plot and compare
#
# One phase-split had about 0.005 difference in phase comp. Let's hope for the best.

# %%
from Stability_and_flash import pr as PR
import numpy as np
import matplotlib.pyplot as plt

# %%
# Instantiate class for ANN
pr = PR()
pr.useModel = True

# %% [markdown]
# At constant T, P, run for loops for z in np.linspace(0,1,100)

# %%
########################################################################################
# INPUTS
T = 500  # [K] [620, 650]
P = 30  # [bar] [10, 30]

# nC4-C10
z = np.array([0.65, 0.35])
w = np.array([0.193, 0.49])
Pc = np.array([37.997, 21.1])  # [bar]
Tc = np.array([425.2, 617.6])  # [K]
BIP = np.zeros([2, 2])

NRtol = 1E-12
NRmaxit = 100  # I think 10 is enough
SStol = 1E-6  #1E-10
tolSSSA = 1E-5
SSmaxit = 500  # 1000000 # 1E6 might crash my computer or take too long.
TolRR = 1E-10
TolXz = 1E-8
itSSSAmax = 1E6

# More global constants
Tr = T / Tc
Pr = P / Pc

Nc = len(z)

phase_num = 1
row_index = 0

# %%
#####################################################################################

# Load models
modelPath = [
    r'C:\Users\win7\Desktop\logs\logs\scalars\lnphi_nC4_T300-600_P5-100__100_4_20_100_20200916-112226',
    r'C:\Users\win7\Desktop\logs\logs\scalars\lnphi_nC10_T300-600_P5-100__100_4_20_100_20200915-230243'
]
pipelinePath = [
    r'C:\Users\win7\Desktop\logs\logs\scalars\lnphi_nC4_T300-600_P5-100__100_4_20_100_20200916-112226\full_pipeline_lnphi_nC4_T300-600_P5-100__100_4_20_100_.pkl',
    r'C:\Users\win7\Desktop\logs\logs\scalars\lnphi_nC10_T300-600_P5-100__100_4_20_100_20200915-230243\full_pipeline_lnphi_nC4_T300-600_P5-100__100_4_20_100_.pkl'
]
pr.load_ANN_model(modelPath, pipelinePath)
# Out:
# Model loading successful.

# %%
ANN_lcomp = []
ANN_vcomp = []
ANN_z = []
for z[0] in np.linspace(0.001, 0.999, 50):
    z[1] = 1.-z[0]

    # Parameters independent of composition placed out of loop.
    # Used in either stability analysis or 2-phase PT flash.

    # Get all K-values from Wilson
    K = pr.wilson_corr(Pr, Tr, w)
    ln_K = np.log(K)

    # Get all ai, bi values
    a_i, b_i = pr.aibi(P, T, w, Pr, Tr, Pc, Tc)

    # Get Vw mixing, part with BIPs and square roots
    Am = pr.Vw(Nc,a_i,BIP)
    ##########################################################################################
    # Debug
    pr.tmp_list = []
    pr.z_list = []
    # Stability Analysis
    # Calculate constants ln_phi(z) ln(z[i])

    sumXX_list, liq_case, vap_case = pr.stability_analysis(T, P, z, b_i, Am, tolSSSA, itSSSAmax, Nc, K, TolXz)

    print('At P = %s bar, and T = %s K' % (P, T))
    if liq_case < 0 or vap_case < 0:
        print('Run 2-phase flash.')
        phase_num = 2
        liq_comp, vap_comp = pr.two_phase_flash_iterate(Pr, Tr, w, SSmaxit, SStol, TolRR, Nc, Am, b_i, NRmaxit, z) #todo: Update Stability_and_flash
        print('liq and vap comp:')
        print(liq_comp, vap_comp)
        
        # Store phase comps for plotting
        ANN_lcomp.append(list(liq_comp))
        ANN_vcomp.append(list(vap_comp))
        ANN_z.append(list(z))
    elif liq_case > 0 and vap_case > 0:
        print('Single phase stable')
        print('P = %s bar, T = %s K' % (P, T))
        print('Liq case: %d, Vap case: %d' % (liq_case, vap_case))
        # Copy single phase composition
        
print('END')
# Out:
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 2
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: -0.27445738913323775
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.8990467270817645
# Liquid comp: [0.4586817 0.5413183]
# Vapor comp: [0.85448427 0.14551573]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -1.0671910237911013
# Liquid comp: [0.48503489 0.51496511]
# Vapor comp: [0.84316968 0.15683032]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -1.1126122357074968
# Liquid comp: [0.49160415 0.50839585]
# Vapor comp: [0.84102284 0.15897716]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -1.1246824275871685
# Liquid comp: [0.49339076 0.50660924]
# Vapor comp: [0.84064785 0.15935215]
# K old: [1.7038177 0.3145465]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -1.1278218556284614
# Liquid comp: [0.49387637 0.50612363]
# Vapor comp: [0.8405975 0.1594025]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -1.1286362799934704
# Liquid comp: [0.49400877 0.50599123]
# Vapor comp: [0.84059706 0.15940294]
# K old: [1.7015831  0.31503102]
# K new: [1.701465   0.31504703]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -1.1288480695372811
# Liquid comp: [0.49404501 0.50595499]
# Vapor comp: [0.84060037 0.15939963]
# K old: [1.701465   0.31504703]
# K new: [1.7014357 0.3150498]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -1.1289009405762893
# Liquid comp: [0.49405439 0.50594561]
# Vapor comp: [0.84060191 0.15939809]
# K old: [1.7014357 0.3150498]
# K new: [1.7014266 0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -1.1289173846148364
# Liquid comp: [0.49405749 0.50594251]
# Vapor comp: [0.84060273 0.15939727]
# Exit flag:1
# K old: [1.7014266 0.3150501]
# K new: [1.701425  0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -1.1289204207046681
# Liquid comp: [0.49405815 0.50594185]
# Vapor comp: [0.84060296 0.15939704]
# K old: [1.701425  0.3150501]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -1.1289223577504557
# Liquid comp: [0.49405874 0.50594126]
# Vapor comp: [0.84060335 0.15939665]
# Exit flag:1
# K old: [1.701424   0.31504974]
# K new: [1.7014245 0.3150498]
# ########################################
# SS Flash outer loop count: 12
# Vapor frac: -1.1289215018823158
# Liquid comp: [0.49405861 0.50594139]
# Vapor comp: [0.84060329 0.15939671]
# Exit flag:2
# K old: [1.7014245 0.3150498]
# K new: [1.701425   0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405861 0.50594139] [0.84060329 0.15939671]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: -0.2428012263531769
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.8475884288734103
# Liquid comp: [0.45868175 0.54131825]
# Vapor comp: [0.85448429 0.14551571]
# K old: [1.8629133 0.2688173]
# K new: [1.7383679 0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -1.0103221678242178
# Liquid comp: [0.48503536 0.51496464]
# Vapor comp: [0.84316985 0.15683015]
# K old: [1.7383679 0.3045455]
# K new: [1.7107708 0.3127033]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -1.0543256589015377
# Liquid comp: [0.49160491 0.50839509]
# Vapor comp: [0.8410232 0.1589768]
# K old: [1.7107708 0.3127033]
# K new: [1.7038171  0.31454673]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -1.0660312963785554
# Liquid comp: [0.49339084 0.50660916]
# Vapor comp: [0.84064775 0.15935225]
# K old: [1.7038171  0.31454673]
# K new: [1.7020403 0.3149479]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -1.0690790442407099
# Liquid comp: [0.49387633 0.50612367]
# Vapor comp: [0.84059741 0.15940259]
# K old: [1.7020403 0.3149479]
# K new: [1.7015826  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -1.0698720865266376
# Liquid comp: [0.49400907 0.50599093]
# Vapor comp: [0.84059717 0.15940283]
# K old: [1.7015826  0.31503102]
# K new: [1.7014656  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -1.0700763346154623
# Liquid comp: [0.49404497 0.50595503]
# Vapor comp: [0.84060049 0.15939951]
# K old: [1.7014656  0.31504682]
# K new: [1.7014353 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -1.070129569400378
# Liquid comp: [0.49405471 0.50594529]
# Vapor comp: [0.84060214 0.15939786]
# K old: [1.7014353 0.3150496]
# K new: [1.7014276  0.31504992]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -1.070143177751388
# Liquid comp: [0.49405739 0.50594261]
# Vapor comp: [0.84060283 0.15939717]
# K old: [1.7014276  0.31504992]
# K new: [1.7014256  0.31504974]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -1.070146889261682
# Liquid comp: [0.49405818 0.50594182]
# Vapor comp: [0.84060317 0.15939683]
# K old: [1.7014256  0.31504974]
# K new: [1.7014245 0.3150501]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -1.0701487651190964
# Liquid comp: [0.49405836 0.50594164]
# Vapor comp: [0.84060303 0.15939697]
# Exit flag:1
# K old: [1.7014245 0.3150501]
# K new: [1.701424   0.31504995]
# ########################################
# SS Flash outer loop count: 12
# Vapor frac: -1.0701496304788978
# Liquid comp: [0.49405866 0.50594134]
# Vapor comp: [0.84060322 0.15939678]
# Exit flag:2
# K old: [1.701424   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405866 0.50594134] [0.84060322 0.15939678]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 3
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.010448075887310164
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.4359215741278898
# Liquid comp: [0.45868174 0.54131826]
# Vapor comp: [0.85448429 0.14551571]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -0.5553553495350122
# Liquid comp: [0.48503492 0.51496508]
# Vapor comp: [0.8431697 0.1568303]
# K old: [1.738369  0.3045455]
# K new: [1.7107723 0.3127033]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -0.5880091775975362
# Liquid comp: [0.49160425 0.50839575]
# Vapor comp: [0.84102296 0.15897704]
# K old: [1.7107723 0.3127033]
# K new: [1.7038187 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -0.5968124124822656
# Liquid comp: [0.49339037 0.50660963]
# Vapor comp: [0.84064772 0.15935228]
# K old: [1.7038187 0.3145465]
# K new: [1.7020409  0.31494737]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -0.5991365724320067
# Liquid comp: [0.49387633 0.50612367]
# Vapor comp: [0.84059769 0.15940231]
# K old: [1.7020409  0.31494737]
# K new: [1.7015836  0.31503087]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -0.5997483983053536
# Liquid comp: [0.4940087 0.5059913]
# Vapor comp: [0.84059712 0.15940288]
# K old: [1.7015836  0.31503087]
# K new: [1.7014656  0.31504703]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -0.5999097547347566
# Liquid comp: [0.49404488 0.50595512]
# Vapor comp: [0.84060035 0.15939965]
# K old: [1.7014656  0.31504703]
# K new: [1.7014347 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -0.5999529093652669
# Liquid comp: [0.49405494 0.50594506]
# Vapor comp: [0.84060222 0.15939778]
# K old: [1.7014347 0.3150496]
# K new: [1.701428   0.31504995]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -0.5999624315009036
# Liquid comp: [0.49405717 0.50594283]
# Vapor comp: [0.84060274 0.15939726]
# K old: [1.701428   0.31504995]
# K new: [1.701425  0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -0.5999668181810829
# Liquid comp: [0.49405821 0.50594179]
# Vapor comp: [0.84060299 0.15939701]
# Exit flag:1
# K old: [1.701425  0.3150501]
# K new: [1.701424   0.31505018]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -0.5999681788579644
# Liquid comp: [0.49405854 0.50594146]
# Vapor comp: [0.84060305 0.15939695]
# Exit flag:2
# K old: [1.701424   0.31505018]
# K new: [1.701424   0.31505018]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405854 0.50594146] [0.84060305 0.15939695]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.042104238667371036
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.3844632417781923
# Liquid comp: [0.45868175 0.54131825]
# Vapor comp: [0.85448429 0.14551571]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -0.498484827086579
# Liquid comp: [0.48503494 0.51496506]
# Vapor comp: [0.84316971 0.15683029]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -0.5297199017837119
# Liquid comp: [0.4916042 0.5083958]
# Vapor comp: [0.84102287 0.15897713]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -0.5381617242278907
# Liquid comp: [0.49339067 0.50660933]
# Vapor comp: [0.84064781 0.15935219]
# K old: [1.7038177 0.3145465]
# K new: [1.7020409  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -0.5403935756277887
# Liquid comp: [0.49387618 0.50612382]
# Vapor comp: [0.84059744 0.15940256]
# K old: [1.7020409  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -0.5409837280804833
# Liquid comp: [0.49400882 0.50599118]
# Vapor comp: [0.84059708 0.15940292]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -0.5411384056934567
# Liquid comp: [0.49404479 0.50595521]
# Vapor comp: [0.84060043 0.15939957]
# K old: [1.7014661  0.31504682]
# K new: [1.7014357 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -0.5411794463252366
# Liquid comp: [0.49405458 0.50594542]
# Vapor comp: [0.8406021 0.1593979]
# K old: [1.7014357 0.3150496]
# K new: [1.7014287  0.31504974]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -0.541189189772124
# Liquid comp: [0.49405705 0.50594295]
# Vapor comp: [0.84060281 0.15939719]
# K old: [1.7014287  0.31504974]
# K new: [1.7014256  0.31504974]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -0.5411935588320973
# Liquid comp: [0.4940581 0.5059419]
# Vapor comp: [0.84060313 0.15939687]
# Exit flag:1
# K old: [1.7014256  0.31504974]
# K new: [1.7014245  0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -0.5411949491272422
# Liquid comp: [0.49405847 0.50594153]
# Vapor comp: [0.84060315 0.15939685]
# Exit flag:2
# K old: [1.7014245  0.31504995]
# K new: [1.701425  0.3150498]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405847 0.50594153] [0.84060315 0.15939685]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 3
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.10541656422749283
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.2815465686554771
# Liquid comp: [0.45868174 0.54131826]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -0.38474350714499594
# Liquid comp: [0.48503491 0.51496509]
# Vapor comp: [0.84316969 0.15683031]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -0.4131414122367253
# Liquid comp: [0.49160421 0.50839579]
# Vapor comp: [0.84102287 0.15897713]
# K old: [1.7107723  0.31270346]
# K new: [1.7038187  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -0.4208562089878604
# Liquid comp: [0.4933903 0.5066097]
# Vapor comp: [0.8406476 0.1593524]
# K old: [1.7038187  0.31454667]
# K new: [1.7020414  0.31494752]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -0.4229077515344479
# Liquid comp: [0.49387607 0.50612393]
# Vapor comp: [0.84059753 0.15940247]
# K old: [1.7020414  0.31494752]
# K new: [1.7015836  0.31503087]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -0.42345268074798204
# Liquid comp: [0.49400866 0.50599134]
# Vapor comp: [0.8405971 0.1594029]
# K old: [1.7015836  0.31503087]
# K new: [1.701465   0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -0.4235982646462534
# Liquid comp: [0.49404514 0.50595486]
# Vapor comp: [0.84060053 0.15939947]
# K old: [1.701465   0.31504682]
# K new: [1.7014347 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -0.42363634426064434
# Liquid comp: [0.49405493 0.50594507]
# Vapor comp: [0.84060222 0.15939778]
# K old: [1.7014347 0.3150496]
# K new: [1.701428   0.31504995]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -0.4236448971905284
# Liquid comp: [0.49405716 0.50594284]
# Vapor comp: [0.84060273 0.15939727]
# K old: [1.701428   0.31504995]
# K new: [1.701425  0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -0.42364895539847297
# Liquid comp: [0.49405822 0.50594178]
# Vapor comp: [0.84060299 0.15939701]
# Exit flag:1
# K old: [1.701425  0.3150501]
# K new: [1.701424   0.31505018]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -0.42365015806969
# Liquid comp: [0.49405853 0.50594147]
# Vapor comp: [0.84060305 0.15939695]
# Exit flag:2
# K old: [1.701424   0.31505018]
# K new: [1.701424   0.31505018]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405853 0.50594147] [0.84060305 0.15939695]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.16872888978761458
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.1786298377243146
# Liquid comp: [0.45868173 0.54131827]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -0.2710023244179541
# Liquid comp: [0.48503494 0.51496506]
# Vapor comp: [0.84316971 0.15683029]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -0.2965629512564337
# Liquid comp: [0.49160422 0.50839578]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -0.3035533443618243
# Liquid comp: [0.49339063 0.50660937]
# Vapor comp: [0.84064771 0.15935229]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -0.3054235172855288
# Liquid comp: [0.49387639 0.50612361]
# Vapor comp: [0.84059751 0.15940249]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -0.30592272160885825
# Liquid comp: [0.49400881 0.50599119]
# Vapor comp: [0.84059708 0.15940292]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -0.3060552383200895
# Liquid comp: [0.49404477 0.50595523]
# Vapor comp: [0.84060042 0.15939958]
# K old: [1.7014661  0.31504682]
# K new: [1.7014353 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -0.30609120983587645
# Liquid comp: [0.49405472 0.50594528]
# Vapor comp: [0.84060215 0.15939785]
# K old: [1.7014353 0.3150496]
# K new: [1.701428  0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -0.30609979695148454
# Liquid comp: [0.49405712 0.50594288]
# Vapor comp: [0.84060265 0.15939735]
# K old: [1.701428  0.3150501]
# K new: [1.7014256 0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -0.30610288897260074
# Liquid comp: [0.494058 0.505942]
# Vapor comp: [0.84060292 0.15939708]
# Exit flag:1
# K old: [1.7014256 0.3150501]
# K new: [1.7014245  0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -0.30610439377184834
# Liquid comp: [0.49405845 0.50594155]
# Vapor comp: [0.84060314 0.15939686]
# Exit flag:2
# K old: [1.7014245  0.31504995]
# K new: [1.701425   0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405845 0.50594155] [0.84060314 0.15939686]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.20038505256767544
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: -0.12717145045917919
# Liquid comp: [0.45868174 0.54131826]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: -0.21413165007767646
# Liquid comp: [0.48503494 0.51496506]
# Vapor comp: [0.84316971 0.15683029]
# K old: [1.738369  0.3045455]
# K new: [1.7107729  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -0.23827300220834455
# Liquid comp: [0.49160402 0.50839598]
# Vapor comp: [0.84102282 0.15897718]
# K old: [1.7107729  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -0.24490120118976574
# Liquid comp: [0.49339061 0.50660939]
# Vapor comp: [0.8406477 0.1593523]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -0.24668078550966535
# Liquid comp: [0.49387637 0.50612363]
# Vapor comp: [0.8405975 0.1594025]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -0.24715745634815764
# Liquid comp: [0.4940088 0.5059912]
# Vapor comp: [0.84059707 0.15940293]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -0.2472845425554938
# Liquid comp: [0.49404479 0.50595521]
# Vapor comp: [0.84060043 0.15939957]
# K old: [1.7014661  0.31504682]
# K new: [1.7014357 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -0.2473186308802645
# Liquid comp: [0.49405459 0.50594541]
# Vapor comp: [0.84060211 0.15939789]
# K old: [1.7014357 0.3150496]
# K new: [1.7014287  0.31504974]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -0.2473268859989818
# Liquid comp: [0.49405704 0.50594296]
# Vapor comp: [0.8406028 0.1593972]
# K old: [1.7014287  0.31504974]
# K new: [1.7014256  0.31504995]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -0.24733047836566083
# Liquid comp: [0.49405807 0.50594193]
# Vapor comp: [0.84060302 0.15939698]
# Exit flag:1
# K old: [1.7014256  0.31504995]
# K new: [1.701424   0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -0.24733237701838504
# Liquid comp: [0.49405864 0.50594136]
# Vapor comp: [0.8406032 0.1593968]
# Exit flag:2
# K old: [1.701424   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405864 0.50594136] [0.8406032 0.1593968]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 3
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 3
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.32700970368791904
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.0786619440008913
# Liquid comp: [0.45868171 0.54131829]
# Vapor comp: [0.85448427 0.14551573]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.013350802073794365
# Liquid comp: [0.48503496 0.51496504]
# Vapor comp: [0.84316972 0.15683028]
# K old: [1.738369  0.3045455]
# K new: [1.7107723 0.3127033]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: -0.005116947800414179
# Liquid comp: [0.49160429 0.50839571]
# Vapor comp: [0.84102298 0.15897702]
# K old: [1.7107723 0.3127033]
# K new: [1.7038177 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: -0.010293163587142856
# Liquid comp: [0.49339071 0.50660929]
# Vapor comp: [0.84064783 0.15935217]
# K old: [1.7038177 0.3145465]
# K new: [1.7020403  0.31494752]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: -0.011710091730489466
# Liquid comp: [0.49387648 0.50612352]
# Vapor comp: [0.84059766 0.15940234]
# K old: [1.7020403  0.31494752]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: -0.012096428267947669
# Liquid comp: [0.49400879 0.50599121]
# Vapor comp: [0.84059707 0.15940293]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: -0.012201415001158062
# Liquid comp: [0.4940448 0.5059552]
# Vapor comp: [0.84060043 0.15939957]
# K old: [1.7014661  0.31504682]
# K new: [1.7014357 0.3150498]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: -0.012229776209956862
# Liquid comp: [0.49405454 0.50594546]
# Vapor comp: [0.84060199 0.15939801]
# K old: [1.7014357 0.3150498]
# K new: [1.7014287 0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: -0.012236730677689047
# Liquid comp: [0.49405693 0.50594307]
# Vapor comp: [0.84060259 0.15939741]
# K old: [1.7014287 0.3150501]
# K new: [1.7014256  0.31504995]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: -0.012240064477204127
# Liquid comp: [0.49405807 0.50594193]
# Vapor comp: [0.84060302 0.15939698]
# Exit flag:1
# K old: [1.7014256  0.31504995]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: -0.012241892700106016
# Liquid comp: [0.49405868 0.50594132]
# Vapor comp: [0.84060332 0.15939668]
# Exit flag:2
# K old: [1.701424   0.31504974]
# K new: [1.701424  0.3150496]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405868 0.50594132] [0.84060332 0.15939668]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.3586658664679799
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.13012025298372695
# Liquid comp: [0.45868175 0.54131825]
# Vapor comp: [0.85448429 0.14551571]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.07022143606347649
# Liquid comp: [0.48503493 0.51496507]
# Vapor comp: [0.8431697 0.1568303]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.05317246613106535
# Liquid comp: [0.49160421 0.50839579]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.04835912007675303
# Liquid comp: [0.49339062 0.50660938]
# Vapor comp: [0.8406477 0.1593523]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.04703285580955265
# Liquid comp: [0.4938764 0.5061236]
# Vapor comp: [0.84059751 0.15940249]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503087]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.04666864816469972
# Liquid comp: [0.49400888 0.50599112]
# Vapor comp: [0.84059718 0.15940282]
# K old: [1.7015831  0.31503087]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.04656941981392046
# Liquid comp: [0.49404476 0.50595524]
# Vapor comp: [0.84060041 0.15939959]
# K old: [1.7014661  0.31504682]
# K new: [1.7014353 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.04654180254040062
# Liquid comp: [0.49405473 0.50594527]
# Vapor comp: [0.84060216 0.15939784]
# K old: [1.7014353 0.3150496]
# K new: [1.701428  0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.046535214793117424
# Liquid comp: [0.49405711 0.50594289]
# Vapor comp: [0.84060264 0.15939736]
# K old: [1.701428  0.3150501]
# K new: [1.7014256 0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.04653265098930015
# Liquid comp: [0.49405804 0.50594196]
# Vapor comp: [0.84060294 0.15939706]
# Exit flag:1
# K old: [1.7014256 0.3150501]
# K new: [1.701424   0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.04653096659388604
# Liquid comp: [0.49405862 0.50594138]
# Vapor comp: [0.84060319 0.15939681]
# Exit flag:2
# K old: [1.701424   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405862 0.50594138] [0.84060319 0.15939681]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.39032202924804077
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.18157864934166437
# Liquid comp: [0.45868171 0.54131829]
# Vapor comp: [0.85448427 0.14551573]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.12709206710430596
# Liquid comp: [0.48503493 0.51496507]
# Vapor comp: [0.8431697 0.1568303]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.11146173835187667
# Liquid comp: [0.49160421 0.50839579]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.1070111571333951
# Liquid comp: [0.49339065 0.50660935]
# Vapor comp: [0.84064772 0.15935228]
# K old: [1.7038177  0.31454667]
# K new: [1.7020409  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.1057762098103785
# Liquid comp: [0.49387614 0.50612386]
# Vapor comp: [0.84059742 0.15940258]
# K old: [1.7020409  0.31494775]
# K new: [1.7015826  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.10543351828602748
# Liquid comp: [0.49400902 0.50599098]
# Vapor comp: [0.84059714 0.15940286]
# K old: [1.7015826  0.31503102]
# K new: [1.7014656  0.31504703]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.10534001548588841
# Liquid comp: [0.49404487 0.50595513]
# Vapor comp: [0.84060034 0.15939966]
# K old: [1.7014656  0.31504703]
# K new: [1.7014347 0.3150498]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.1053136875529318
# Liquid comp: [0.49405486 0.50594514]
# Vapor comp: [0.84060209 0.15939791]
# K old: [1.7014347 0.3150498]
# K new: [1.701429   0.31505015]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.10530864481098805
# Liquid comp: [0.49405677 0.50594323]
# Vapor comp: [0.84060251 0.15939749]
# K old: [1.701429   0.31505015]
# K new: [1.7014256 0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.10530527423453924
# Liquid comp: [0.494058 0.505942]
# Vapor comp: [0.84060292 0.15939708]
# K old: [1.7014256 0.3150501]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.10530345541223696
# Liquid comp: [0.49405868 0.50594132]
# Vapor comp: [0.84060332 0.15939668]
# Exit flag:1
# K old: [1.701424   0.31504974]
# K new: [1.701424  0.3150496]
# ########################################
# SS Flash outer loop count: 12
# Vapor frac: 0.10530322667712617
# Liquid comp: [0.49405876 0.50594124]
# Vapor comp: [0.84060342 0.15939658]
# Exit flag:2
# K old: [1.701424  0.3150496]
# K new: [1.701424  0.3150498]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405876 0.50594124] [0.84060342 0.15939658]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.42197819202810155
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.2330369605808186
# Liquid comp: [0.45868173 0.54131827]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.1839627035357784
# Liquid comp: [0.48503494 0.51496506]
# Vapor comp: [0.84316971 0.15683029]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.1697509811085897
# Liquid comp: [0.4916042 0.5083958]
# Vapor comp: [0.84102287 0.15897713]
# K old: [1.7107723  0.31270346]
# K new: [1.7038182 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.1656634204419015
# Liquid comp: [0.49339054 0.50660946]
# Vapor comp: [0.84064777 0.15935223]
# K old: [1.7038182 0.3145465]
# K new: [1.7020403  0.31494752]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.1645180102663846
# Liquid comp: [0.49387647 0.50612353]
# Vapor comp: [0.84059765 0.15940235]
# K old: [1.7020403  0.31494752]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.16419934839546266
# Liquid comp: [0.49400881 0.50599119]
# Vapor comp: [0.84059708 0.15940292]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.16411102479678924
# Liquid comp: [0.49404477 0.50595523]
# Vapor comp: [0.84060041 0.15939959]
# K old: [1.7014661  0.31504682]
# K new: [1.7014353 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.1640862292423562
# Liquid comp: [0.49405471 0.50594529]
# Vapor comp: [0.84060214 0.15939786]
# K old: [1.7014353 0.3150496]
# K new: [1.7014276  0.31504992]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.16407946398689371
# Liquid comp: [0.49405737 0.50594263]
# Vapor comp: [0.84060282 0.15939718]
# K old: [1.7014276  0.31504992]
# K new: [1.7014256  0.31504974]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.16407746270084517
# Liquid comp: [0.49405814 0.50594186]
# Vapor comp: [0.84060315 0.15939685]
# Exit flag:1
# K old: [1.7014256  0.31504974]
# K new: [1.7014245 0.3150496]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.16407630215145916
# Liquid comp: [0.49405857 0.50594143]
# Vapor comp: [0.84060336 0.15939664]
# Exit flag:2
# K old: [1.7014245 0.3150496]
# K new: [1.701424  0.3150498]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405857 0.50594143] [0.84060336 0.15939664]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.4536343548081625
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.28449531436104075
# Liquid comp: [0.45868173 0.54131827]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.24083328883005964
# Liquid comp: [0.48503496 0.51496504]
# Vapor comp: [0.84316972 0.15683028]
# K old: [1.738369  0.3045455]
# K new: [1.7107723 0.3127033]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.22803998505616202
# Liquid comp: [0.49160429 0.50839571]
# Vapor comp: [0.84102298 0.15897702]
# K old: [1.7107723 0.3127033]
# K new: [1.7038177 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.22431508087269578
# Liquid comp: [0.49339069 0.50660931]
# Vapor comp: [0.84064782 0.15935218]
# K old: [1.7038177 0.3145465]
# K new: [1.7020409  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.223261552068236
# Liquid comp: [0.49387619 0.50612381]
# Vapor comp: [0.84059745 0.15940255]
# K old: [1.7020409  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.22296459776887495
# Liquid comp: [0.49400879 0.50599121]
# Vapor comp: [0.84059707 0.15940293]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.22288179408483408
# Liquid comp: [0.49404476 0.50595524]
# Vapor comp: [0.84060041 0.15939959]
# K old: [1.7014661  0.31504682]
# K new: [1.7014353 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.222858364209779
# Liquid comp: [0.49405474 0.50594526]
# Vapor comp: [0.84060216 0.15939784]
# K old: [1.7014353 0.3150496]
# K new: [1.701428  0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.2228527033629493
# Liquid comp: [0.49405711 0.50594289]
# Vapor comp: [0.84060264 0.15939736]
# K old: [1.701428  0.3150501]
# K new: [1.7014256 0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.222850498052548
# Liquid comp: [0.494058 0.505942]
# Vapor comp: [0.84060292 0.15939708]
# K old: [1.7014256 0.3150501]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.22284877898983427
# Liquid comp: [0.49405866 0.50594134]
# Vapor comp: [0.8406033 0.1593967]
# Exit flag:1
# K old: [1.701424   0.31504974]
# K new: [1.7014245  0.31504995]
# ########################################
# SS Flash outer loop count: 12
# Vapor frac: 0.22284935171410744
# Liquid comp: [0.49405845 0.50594155]
# Vapor comp: [0.84060314 0.15939686]
# Exit flag:2
# K old: [1.7014245  0.31504995]
# K new: [1.701425   0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405845 0.50594155] [0.84060314 0.15939686]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.48529051758822334
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.3359537172539179
# Liquid comp: [0.45868173 0.54131827]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.2977038844186272
# Liquid comp: [0.48503495 0.51496505]
# Vapor comp: [0.84316971 0.15683029]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.28632944318208464
# Liquid comp: [0.49160422 0.50839578]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.2829674046053199
# Liquid comp: [0.49339062 0.50660938]
# Vapor comp: [0.8406477 0.1593523]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.28200378983936486
# Liquid comp: [0.49387638 0.50612362]
# Vapor comp: [0.84059751 0.15940249]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.2817298082901228
# Liquid comp: [0.49400882 0.50599118]
# Vapor comp: [0.84059708 0.15940292]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.28165253043052485
# Liquid comp: [0.49404479 0.50595521]
# Vapor comp: [0.84060042 0.15939958]
# K old: [1.7014661  0.31504682]
# K new: [1.7014357 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.2816308283407539
# Liquid comp: [0.4940546 0.5059454]
# Vapor comp: [0.84060211 0.15939789]
# K old: [1.7014357 0.3150496]
# K new: [1.7014287  0.31504974]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.2816252279236466
# Liquid comp: [0.49405702 0.50594298]
# Vapor comp: [0.84060279 0.15939721]
# K old: [1.7014287  0.31504974]
# K new: [1.7014256  0.31504995]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.28162290328239353
# Liquid comp: [0.49405806 0.50594194]
# Vapor comp: [0.84060302 0.15939698]
# Exit flag:1
# K old: [1.7014256  0.31504995]
# K new: [1.701424   0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.2816216426216619
# Liquid comp: [0.49405861 0.50594139]
# Vapor comp: [0.84060319 0.15939681]
# Exit flag:2
# K old: [1.701424   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405861 0.50594139] [0.84060319 0.15939681]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.5169466803682844
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.3874120394618862
# Liquid comp: [0.45868173 0.54131827]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.354574549629575
# Liquid comp: [0.48503493 0.51496507]
# Vapor comp: [0.8431697 0.1568303]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.34461867229178905
# Liquid comp: [0.49160422 0.50839578]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.3416194962287804
# Liquid comp: [0.49339061 0.50660939]
# Vapor comp: [0.8406477 0.1593523]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.3407465774807435
# Liquid comp: [0.49387637 0.50612363]
# Vapor comp: [0.8405975 0.1594025]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.3404950688030834
# Liquid comp: [0.4940088 0.5059912]
# Vapor comp: [0.84059707 0.15940293]
# K old: [1.7015831  0.31503102]
# K new: [1.7014661  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.3404233395289179
# Liquid comp: [0.49404477 0.50595523]
# Vapor comp: [0.84060042 0.15939958]
# K old: [1.7014661  0.31504682]
# K new: [1.7014353 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.3404027093141708
# Liquid comp: [0.49405471 0.50594529]
# Vapor comp: [0.84060215 0.15939785]
# K old: [1.7014353 0.3150496]
# K new: [1.701428  0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.34039769319027063
# Liquid comp: [0.4940571 0.5059429]
# Vapor comp: [0.84060264 0.15939736]
# K old: [1.701428  0.3150501]
# K new: [1.7014256 0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.34039570897281785
# Liquid comp: [0.49405801 0.50594199]
# Vapor comp: [0.84060293 0.15939707]
# K old: [1.7014256 0.3150501]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.34039404344095986
# Liquid comp: [0.49405867 0.50594133]
# Vapor comp: [0.84060331 0.15939669]
# Exit flag:1
# K old: [1.701424   0.31504974]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 12
# Vapor frac: 0.340394049199127
# Liquid comp: [0.49405867 0.50594133]
# Vapor comp: [0.84060331 0.15939669]
# Exit flag:2
# K old: [1.701424   0.31504974]
# K new: [1.701424   0.31504974]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405867 0.50594133] [0.84060331 0.15939669]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.5486028431483452
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.43887040919303594
# Liquid comp: [0.45868172 0.54131828]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.41144519234142013
# Liquid comp: [0.48503492 0.51496508]
# Vapor comp: [0.8431697 0.1568303]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.4029079075719518
# Liquid comp: [0.49160421 0.50839579]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.4002715143493832
# Liquid comp: [0.49339062 0.50660938]
# Vapor comp: [0.8406477 0.1593523]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.3994892783177809
# Liquid comp: [0.49387637 0.50612363]
# Vapor comp: [0.8405975 0.1594025]
# K old: [1.7020403  0.31494775]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.3992603880070197
# Liquid comp: [0.49400877 0.50599123]
# Vapor comp: [0.84059705 0.15940295]
# K old: [1.7015831  0.31503102]
# K new: [1.701465   0.31504703]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.3991935902101769
# Liquid comp: [0.4940451 0.5059549]
# Vapor comp: [0.84060042 0.15939958]
# K old: [1.701465   0.31504703]
# K new: [1.7014353  0.31504935]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.3991745611592395
# Liquid comp: [0.49405481 0.50594519]
# Vapor comp: [0.8406023 0.1593977]
# K old: [1.7014353  0.31504935]
# K new: [1.701428   0.31504974]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.39916973409797957
# Liquid comp: [0.49405723 0.50594277]
# Vapor comp: [0.84060286 0.15939714]
# K old: [1.701428   0.31504974]
# K new: [1.7014256  0.31504974]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.39916787371128576
# Liquid comp: [0.49405815 0.50594185]
# Vapor comp: [0.84060315 0.15939685]
# Exit flag:1
# K old: [1.7014256  0.31504974]
# K new: [1.7014245 0.3150496]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.39916678236485326
# Liquid comp: [0.49405856 0.50594144]
# Vapor comp: [0.84060335 0.15939665]
# Exit flag:2
# K old: [1.7014245 0.3150496]
# K new: [1.7014245 0.3150498]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405856 0.50594144] [0.84060335 0.15939665]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.580259005928406
# Liquid comp: [0.27942064 0.72057936]
# ...
# SS Flash outer loop count: 12
# Vapor frac: 0.8693485985661373
# Liquid comp: [0.4940583 0.5059417]
# Vapor comp: [0.8406031 0.1593969]
# Exit flag:2
# K old: [1.701425   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.4940583 0.5059417] [0.8406031 0.1593969]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.8335083081688931
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.9019956024214758
# Liquid comp: [0.45868174 0.54131826]
# Vapor comp: [0.85448428 0.14551572]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.9232808136165696
# Liquid comp: [0.4850349 0.5149651]
# Vapor comp: [0.84316969 0.15683031]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.9275110683290495
# Liquid comp: [0.4916042 0.5083958]
# Vapor comp: [0.84102287 0.15897713]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177 0.3145465]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.9281398386409115
# Liquid comp: [0.4933907 0.5066093]
# Vapor comp: [0.84064782 0.15935218]
# K old: [1.7038177 0.3145465]
# K new: [1.7020409  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.9281741248187122
# Liquid comp: [0.49387614 0.50612386]
# Vapor comp: [0.84059742 0.15940258]
# K old: [1.7020409  0.31494775]
# K new: [1.7015826  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.9281474276262841
# Liquid comp: [0.49400899 0.50599101]
# Vapor comp: [0.84059713 0.15940287]
# K old: [1.7015826  0.31503102]
# K new: [1.701465   0.31504717]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.9281313484457828
# Liquid comp: [0.49404505 0.50595495]
# Vapor comp: [0.84060033 0.15939967]
# K old: [1.701465   0.31504717]
# K new: [1.7014353 0.3150498]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.9281247734141849
# Liquid comp: [0.49405465 0.50594535]
# Vapor comp: [0.84060202 0.15939798]
# K old: [1.7014353 0.3150498]
# K new: [1.7014287  0.31504974]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.928122324621944
# Liquid comp: [0.494057 0.505943]
# Vapor comp: [0.84060278 0.15939722]
# K old: [1.7014287  0.31504974]
# K new: [1.7014256  0.31504995]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.9281214441948228
# Liquid comp: [0.49405806 0.50594194]
# Vapor comp: [0.84060302 0.15939698]
# Exit flag:1
# K old: [1.7014256  0.31504995]
# K new: [1.701424   0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.9281209532366543
# Liquid comp: [0.49405858 0.50594142]
# Vapor comp: [0.84060317 0.15939683]
# Exit flag:2
# K old: [1.701424   0.31504995]
# K new: [1.701424   0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405858 0.50594142] [0.84060317 0.15939683]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.865164470948954
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.9534539142221805
# Liquid comp: [0.45868177 0.54131823]
# Vapor comp: [0.8544843 0.1455157]
# K old: [1.8629133 0.2688173]
# K new: [1.7383679 0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.980151080248422
# Liquid comp: [0.4850353 0.5149647]
# Vapor comp: [0.84316982 0.15683018]
# K old: [1.7383679 0.3045455]
# K new: [1.7107718  0.31270316]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.9857995361860683
# Liquid comp: [0.49160446 0.50839554]
# Vapor comp: [0.8410231 0.1589769]
# K old: [1.7107718  0.31270316]
# K new: [1.7038171  0.31454673]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.9867921202802187
# Liquid comp: [0.4933908 0.5066092]
# Vapor comp: [0.84064773 0.15935227]
# K old: [1.7038171  0.31454673]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.9869165708001295
# Liquid comp: [0.49387644 0.50612356]
# Vapor comp: [0.84059754 0.15940246]
# K old: [1.7020403  0.31494775]
# K new: [1.7015836  0.31503087]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.986912733820903
# Liquid comp: [0.49400868 0.50599132]
# Vapor comp: [0.84059711 0.15940289]
# K old: [1.7015836  0.31503087]
# K new: [1.701465   0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.9869016097126527
# Liquid comp: [0.49404516 0.50595484]
# Vapor comp: [0.84060054 0.15939946]
# K old: [1.701465   0.31504682]
# K new: [1.7014347  0.31504944]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.9868961272455732
# Liquid comp: [0.49405502 0.50594498]
# Vapor comp: [0.84060232 0.15939768]
# K old: [1.7014347  0.31504944]
# K new: [1.701428   0.31504974]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.9868945751195665
# Liquid comp: [0.49405726 0.50594274]
# Vapor comp: [0.84060288 0.15939712]
# K old: [1.701428   0.31504974]
# K new: [1.701425   0.31504995]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.9868938817316464
# Liquid comp: [0.49405828 0.50594172]
# Vapor comp: [0.84060309 0.15939691]
# Exit flag:1
# K old: [1.701425   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.9868937471397909
# Liquid comp: [0.49405841 0.50594159]
# Vapor comp: [0.84060312 0.15939688]
# Exit flag:2
# K old: [1.7014245  0.31504995]
# K new: [1.701424   0.31504974]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405841 0.50594159] [0.84060312 0.15939688]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 2
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.9917891220691974
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 1.1592872453795569
# Liquid comp: [0.45868185 0.54131815]
# Vapor comp: [0.85448434 0.14551566]
# K old: [1.8629133 0.2688173]
# K new: [1.7383679 0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 1.207633725523021
# Liquid comp: [0.48503529 0.51496471]
# Vapor comp: [0.84316981 0.15683019]
# K old: [1.7383679 0.3045455]
# K new: [1.7107718  0.31270316]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 1.2189564614572947
# Liquid comp: [0.49160456 0.50839544]
# Vapor comp: [0.84102315 0.15897685]
# K old: [1.7107718  0.31270316]
# K new: [1.7038177  0.31454673]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 1.2214005098087148
# Liquid comp: [0.49339076 0.50660924]
# Vapor comp: [0.84064775 0.15935225]
# K old: [1.7038177  0.31454673]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 1.2218875056524259
# Liquid comp: [0.4938764 0.5061236]
# Vapor comp: [0.84059752 0.15940248]
# K old: [1.7020403  0.31494775]
# K new: [1.7015836  0.31503087]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 1.2219737103803503
# Liquid comp: [0.49400864 0.50599136]
# Vapor comp: [0.84059708 0.15940292]
# K old: [1.7015836  0.31503087]
# K new: [1.7014656  0.31504667]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 1.2219848049247943
# Liquid comp: [0.49404491 0.50595509]
# Vapor comp: [0.84060051 0.15939949]
# K old: [1.7014656  0.31504667]
# K new: [1.7014364 0.3150498]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 1.2219859292687352
# Liquid comp: [0.49405427 0.50594573]
# Vapor comp: [0.8406019 0.1593981]
# K old: [1.7014364 0.3150498]
# K new: [1.701428  0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 1.221985310943274
# Liquid comp: [0.49405698 0.50594302]
# Vapor comp: [0.84060257 0.15939743]
# K old: [1.701428  0.3150501]
# K new: [1.701425  0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 1.2219846916352257
# Liquid comp: [0.49405819 0.50594181]
# Vapor comp: [0.84060298 0.15939702]
# Exit flag:1
# K old: [1.701425  0.3150501]
# K new: [1.701424   0.31505033]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 1.2219850076354388
# Liquid comp: [0.49405851 0.50594149]
# Vapor comp: [0.84060297 0.15939703]
# Exit flag:2
# K old: [1.701424   0.31505033]
# K new: [1.7014245  0.31505018]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405851 0.50594149] [0.84060297 0.15939703]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 3
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 1.0551014476293192
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 1.2622040002258115
# Liquid comp: [0.45868172 0.54131828]
# Vapor comp: [0.85448427 0.14551573]
# K old: [1.8629133 0.2688173]
# K new: [1.738369  0.3045455]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 1.3213750955160568
# Liquid comp: [0.48503488 0.51496512]
# Vapor comp: [0.84316968 0.15683032]
# K old: [1.738369  0.3045455]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 1.335535680291051
# Liquid comp: [0.49160448 0.50839552]
# Vapor comp: [0.84102302 0.15897698]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454673]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 1.3387046705261683
# Liquid comp: [0.49339078 0.50660922]
# Vapor comp: [0.84064776 0.15935224]
# K old: [1.7038177  0.31454673]
# K new: [1.7020403  0.31494775]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 1.3393730815443006
# Liquid comp: [0.49387608 0.50612392]
# Vapor comp: [0.84059734 0.15940266]
# K old: [1.7020403  0.31494775]
# K new: [1.7015826  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 1.339504328922386
# Liquid comp: [0.49400898 0.50599102]
# Vapor comp: [0.84059712 0.15940288]
# K old: [1.7015826  0.31503102]
# K new: [1.701465   0.31504703]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 1.3395270478534456
# Liquid comp: [0.49404509 0.50595491]
# Vapor comp: [0.84060042 0.15939958]
# K old: [1.701465   0.31504703]
# K new: [1.7014347 0.3150496]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 1.3395297771142454
# Liquid comp: [0.49405477 0.50594523]
# Vapor comp: [0.84060213 0.15939787]
# K old: [1.7014347 0.3150496]
# K new: [1.7014276  0.31504995]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 1.33952985776828
# Liquid comp: [0.49405726 0.50594274]
# Vapor comp: [0.84060275 0.15939725]
# K old: [1.7014276  0.31504995]
# K new: [1.701425   0.31504995]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 1.339529631609786
# Liquid comp: [0.49405828 0.50594172]
# Vapor comp: [0.84060309 0.15939691]
# Exit flag:1
# K old: [1.701425   0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 1.3395295401634035
# Liquid comp: [0.49405855 0.50594145]
# Vapor comp: [0.8406032 0.1593968]
# Exit flag:2
# K old: [1.7014245  0.31504995]
# K new: [1.7014245  0.31504995]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405855 0.50594145] [0.8406032 0.1593968]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 1.0867576104093801
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.8629133 0.2688173]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 1.3136623924736353
# Liquid comp: [0.45868146 0.54131854]
# Vapor comp: [0.85448415 0.14551585]
# K old: [1.8629133 0.2688173]
# K new: [1.7383684  0.30454534]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 1.3782454249519316
# Liquid comp: [0.48503476 0.51496524]
# Vapor comp: [0.84316964 0.15683036]
# K old: [1.7383684  0.30454534]
# K new: [1.7107723  0.31270346]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 1.3938249286659519
# Liquid comp: [0.49160423 0.50839577]
# Vapor comp: [0.84102288 0.15897712]
# K old: [1.7107723  0.31270346]
# K new: [1.7038177  0.31454667]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 1.3973568004749528
# Liquid comp: [0.49339084 0.50660916]
# Vapor comp: [0.84064782 0.15935218]
# K old: [1.7038177  0.31454667]
# K new: [1.7020403 0.3149479]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 1.398116088378885
# Liquid comp: [0.49387616 0.50612384]
# Vapor comp: [0.84059732 0.15940268]
# K old: [1.7020403 0.3149479]
# K new: [1.7015831  0.31503102]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 1.3982697003267905
# Liquid comp: [0.49400884 0.50599116]
# Vapor comp: [0.84059709 0.15940291]
# K old: [1.7015831  0.31503102]
# K new: [1.7014645  0.31504682]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 1.3982972535240026
# Liquid comp: [0.49404532 0.50595468]
# Vapor comp: [0.84060059 0.15939941]
# K old: [1.7014645  0.31504682]
# K new: [1.7014353 0.3150498]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 1.3983022929144557
# Liquid comp: [0.49405461 0.50594539]
# Vapor comp: [0.840602 0.159398]
# K old: [1.7014353 0.3150498]
# K new: [1.701429  0.3150501]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 1.3983027621801873
# Liquid comp: [0.49405674 0.50594326]
# Vapor comp: [0.84060252 0.15939748]
# K old: [1.701429  0.3150501]
# K new: [1.7014256 0.3150501]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 1.3983025742352047
# Liquid comp: [0.49405808 0.50594192]
# Vapor comp: [0.84060296 0.15939704]
# K old: [1.7014256 0.3150501]
# K new: [1.701424   0.31504974]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 1.398301773715479
# Liquid comp: [0.49405913 0.50594087]
# Vapor comp: [0.84060356 0.15939644]
# Exit flag:1
# K old: [1.701424   0.31504974]
# K new: [1.701424  0.3150498]
# ########################################
# SS Flash outer loop count: 12
# Vapor frac: 1.3983018429539849
# Liquid comp: [0.49405841 0.50594159]
# Vapor comp: [0.84060314 0.15939686]
# Exit flag:2
# K old: [1.701424  0.3150498]
# K new: [1.7014245 0.3150496]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.49405841 0.50594159] [0.84060314 0.15939686]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# END

# %%
ANN_z = np.array(ANN_z)
ANN_vcomp = np.array(ANN_vcomp)

fig = plt.figure('''figsize=(20,20)''')
ax = fig.add_subplot(111)
ax.plot(ANN_z[:,0], ANN_vcomp[:,0])
ax.set_title(r'ANN $nC_4$ Vapor Composition vs Overall $nC_4$')
ax.set_xlabel(r'$z_{nC_4}$')
ax.set_ylabel(r'$y_{nC_4}$')
# Out:
# Text(0, 0.5, '$y_{nC_4}$')

# %% [markdown]
# As expected, equilibrium phase compositions are constant in 2-phase region.
# Also, there were cases of negative flash reaching convergence. Make sure the returned composition makes sense.

# %% [markdown]
# ## EOS

# %%
pr.useModel = False

# %%
EOS_lcomp = []
EOS_vcomp = []
EOS_z = []
for z[0] in np.linspace(0.001, 0.999, 50):
    z[1] = 1.-z[0]

    # Parameters independent of composition placed out of loop.
    # Used in either stability analysis or 2-phase PT flash.

    # Get all K-values from Wilson
    K = pr.wilson_corr(Pr, Tr, w)
    ln_K = np.log(K)

    # Get all ai, bi values
    a_i, b_i = pr.aibi(P, T, w, Pr, Tr, Pc, Tc)

    # Get Vw mixing, part with BIPs and square roots
    Am = pr.Vw(Nc,a_i,BIP)
    ##########################################################################################
    # Debug
    pr.tmp_list = []
    pr.z_list = []
    # Stability Analysis
    # Calculate constants ln_phi(z) ln(z[i])

    sumXX_list, liq_case, vap_case = pr.stability_analysis(T, P, z, b_i, Am, tolSSSA, itSSSAmax, Nc, K, TolXz)

    print('At P = %s bar, and T = %s K' % (P, T))
    if liq_case < 0 or vap_case < 0:
        print('Run 2-phase flash.')
        phase_num = 2
        liq_comp, vap_comp = pr.two_phase_flash_iterate(Pr, Tr, w, SSmaxit, SStol, TolRR, Nc, Am, b_i, NRmaxit, z) #todo: Update Stability_and_flash
        print('liq and vap comp:')
        print(liq_comp, vap_comp)
        
        # Store phase comps for plotting
        EOS_lcomp.append(list(liq_comp))
        EOS_vcomp.append(list(vap_comp))
        EOS_z.append(list(z))
    elif liq_case > 0 and vap_case > 0:
        print('Single phase stable')
        print('P = %s bar, T = %s K' % (P, T))
        print('Liq case: %d, Vap case: %d' % (liq_case, vap_case))
        # Copy single phase composition
        
print('END')
# Out:
# EOS used in SA Liq. P = 30, T = 500, x_liq = [3.24657098e-05 9.99967534e-01]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00099985 0.99900015]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.001 0.999]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.001 0.999]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.02993845 0.97006155]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.00100461 0.99899539]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.001 0.999]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.001 0.999]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [7.07665373e-04 9.99292335e-01]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02129944 0.97870056]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02136712 0.97863288]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02136735 0.97863265]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02136735 0.97863265]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.40233302 0.59766698]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.0239686 0.9760314]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.02137617 0.97862383]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.02136738 0.97863262]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.02136735 0.97863265]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.0014106 0.9985894]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.04147451 0.95852549]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.04173292 0.95826708]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.04173468 0.95826532]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.04173469 0.95826531]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.57315787 0.42684213]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.05461734 0.94538266]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.04182411 0.95817589]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.0417353 0.9582647]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.0417347 0.9582653]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.04173469 0.95826531]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.002143 0.997857]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.06152333 0.93847667]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.06209598 0.93790402]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.06210198 0.93789802]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.06210204 0.93789796]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.67121304 0.32878696]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.1145827 0.8854173]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.06269623 0.93730377]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.06210827 0.93789173]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.06210211 0.93789789]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.06210204 0.93789796]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00290678 0.99709322]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.08144395 0.91855605]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.08245465 0.91754535]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.08246918 0.91753082]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.08246938 0.91753062]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.73483235 0.26516765]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.30858225 0.69141775]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.08728136 0.91271864]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.08253912 0.91746088]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.08247039 0.91752961]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.0824694 0.9175306]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.08246939 0.91753061]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00370399 0.99629601]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.10123418 0.89876582]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.10280705 0.89719295]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.10283618 0.89716382]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.10283672 0.89716328]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77944648 0.22055352]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.39375344 0.60624656]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.11223097 0.88776903]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.10301366 0.89698634]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.10284002 0.89715998]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.1028368 0.8971632]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.10283674 0.89716326]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00453687 0.99546313]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.12089154 0.87910846]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.12315098 0.87684902]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.12320286 0.87679714]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.12320405 0.87679595]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81246492 0.18753508]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.46057011 0.53942989]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.13889003 0.86110997]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.12357439 0.87642561]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.12321262 0.87678738]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.12320428 0.87679572]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.12320409 0.87679591]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00540787 0.99459213]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.14041325 0.85958675]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.14348394 0.85651606]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.14356899 0.85643101]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.14357136 0.85642864]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.14357143 0.85642857]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83788849 0.16211151]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.51561899 0.48438101]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.16773427 0.83226573]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.14427048 0.85572952]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.14359091 0.85640909]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.14357197 0.85642803]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.14357144 0.85642856]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00631968 0.99368032]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.15979615 0.84020385]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.16380301 0.83619699]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.1639343 0.8360657]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.16393863 0.83606137]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.16393877 0.83606123]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85806736 0.14193264]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.56198766 0.43801234]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.19946695 0.80053305]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.16518149 0.83481851]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.16397986 0.83602014]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.16394013 0.83605987]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.16393882 0.83606118]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00727522 0.99272478]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.17903663 0.82096337]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.18410482 0.81589518]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.18429837 0.81570163]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.18430582 0.81569418]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.18430611 0.81569389]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8744727 0.1255273]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.60162766 0.39837234]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.2353726 0.7646274]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.18645377 0.81354623]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.18438917 0.81561083]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.18430932 0.81569068]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.18430625 0.81569375]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.18430613 0.81569387]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00827772 0.99172228]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.19813058 0.80186942]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.20438544 0.79561456]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.20466066 0.79533934]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.2046729 0.7953271]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.20467344 0.79532656]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.88807249 0.11192751]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.63590851 0.36409149]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.27841081 0.72158919]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.20842061 0.79157939]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.20484131 0.79515869]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.20468094 0.79531906]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.2046738 0.7953262]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.20467348 0.79532652]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.00933073 0.99066927]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.21707332 0.78292668]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.22464029 0.77535971]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.22502042 0.77497958]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.22503978 0.77496022]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.22504076 0.77495924]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89952973 0.10047027]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.66583996 0.33416004]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.33979814 0.66020186]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.23233757 0.76766243]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.22541749 0.77458251]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.22506003 0.77493997]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.2250418 0.7749582]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.22504087 0.77495913]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01043817 0.98956183]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.23585943 0.76414057]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.244864 0.755136]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.24537665 0.75462335]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.24540634 0.75459366]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.24540806 0.75459194]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.90931377 0.09068623]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.69218883 0.30781117]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.54429953 0.45570047]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.28261165 0.71738835]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.24771822 0.75228178]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.24554262 0.75445738]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.24541596 0.75458404]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.24540862 0.75459138]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.24540819 0.75459181]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01160437 0.98839563]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.25448263 0.74551737]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.26505024 0.73494976]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.26572802 0.73427198]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.2657724 0.7342276]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.26577531 0.73422469]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.2657755 0.7342245]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.91776618 0.08223382]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.71554973 0.28445027]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.61155559 0.38844441]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.33037894 0.66962106]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.27058328 0.72941672]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.26609355 0.73390645]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.26579637 0.73420363]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.26577688 0.73422312]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.2657756 0.7342244]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01283412 0.98716588]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.27293562 0.72706438]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.28519153 0.71480847]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.28607273 0.71392727]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.28613768 0.71386232]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.28614247 0.71385753]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.28614283 0.71385717]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.92514151 0.07485849]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.73639124 0.26360876]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.65491671 0.34508329]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.39083503 0.60916497]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.29579637 0.70420363]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.2868691 0.7131309]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.28619656 0.71380344]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.28614682 0.71385318]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.28614315 0.71385685]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.28614288 0.71385712]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01413279 0.98586721]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.29120986 0.70879014]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.30527891 0.69472109]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.30640837 0.69359163]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.30650176 0.69349824]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.3065095 0.6934905]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.30651015 0.69348985]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.9316333 0.0683667]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75508757 0.24491243]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.68866792 0.31133208]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.60249569 0.39750431]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.36727849 0.63272151]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.3122335 0.6877665]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.30699011 0.69300989]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.30655003 0.69344997]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.30651351 0.69348649]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.30651048 0.69348952]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01550631 0.98449369]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.30929524 0.69070476]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.32530168 0.67469832]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.3267317 0.6732683]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.32686401 0.67313599]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.32687629 0.67312371]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.32687743 0.67312257]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.93739134 0.06260866]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77194091 0.22805909]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.71657132 0.28342868]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.67480478 0.32519522]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.48318638 0.51681362]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.34823123 0.65176877]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.32895076 0.67104924]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.32707087 0.67292913]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.32689551 0.67310449]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.32687922 0.67312078]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.32687771 0.67312229]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01696136 0.98303864]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.32717971 0.67282029]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.34524685 0.65475315]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.34703833 0.65296167]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.34722346 0.65277654]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.34724267 0.65275733]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.34724467 0.65275533]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.94253338 0.05746662]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.7871976 0.2128024]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.74034794 0.25965206]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.71369186 0.28630814]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.68930918 0.31069082]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.64418367 0.35581633]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.43978165 0.56021835]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.35920525 0.64079475]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.34851899 0.65148101]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.34737753 0.65262247]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.34725867 0.65274133]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.34724633 0.65275367]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.34724505 0.65275495]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.01850542 0.98149458]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.34484881 0.65515119]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.36509857 0.63490143]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.36732231 0.63267769]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.36757864 0.63242136]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.36760835 0.63239165]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.36761179 0.63238821]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.94715326 0.05284674]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.80105998 0.19894002]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.76098379 0.23901621]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.74239699 0.25760301]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.73097705 0.26902295]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.72246706 0.27753294]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.71503473 0.28496527]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.70746711 0.29253289]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.69827191 0.30172809]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.68377789 0.31622211]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.63647513 0.36352487]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.45127284 0.54872716]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.37952384 0.62047616]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.36903114 0.63096886]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.36777733 0.63222267]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.3676314 0.6323686]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.36761447 0.63238553]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.3676125 0.6323875]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02014691 0.97985309]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.36228495 0.63771505]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.38483726 0.61516274]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.38757546 0.61242454]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.38792729 0.61207271]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.38797282 0.61202718]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.38797871 0.61202129]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.38797948 0.61202052]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95132666 0.04867334]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8136952 0.1863048]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77911786 0.22088214]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.76551355 0.23448645]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.7590237 0.2409763]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75561465 0.24438535]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75372838 0.24627162]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75265374 0.24734626]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75203114 0.24796886]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75166688 0.24833312]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75145255 0.24854745]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.751326 0.248674]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75125113 0.24874887]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75120679 0.24879321]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75118051 0.24881949]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75116492 0.24883508]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75115568 0.24884432]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.7511502 0.2488498]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75114694 0.24885306]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.75114501 0.24885499]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02189536 0.97810464]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.37946651 0.62053349]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.40443845 0.59556155]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.40778641 0.59221359]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.4082659 0.5917341]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.40833521 0.59166479]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.40834524 0.59165476]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.40834669 0.59165331]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95511532 0.04488468]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82524185 0.17475815]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79519662 0.20480338]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.78491699 0.21508301]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.78086435 0.21913565]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77917252 0.22082748]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77844898 0.22155102]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77813633 0.22186367]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77800062 0.22199938]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77794159 0.22205841]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.7779159 0.2220841]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77790471 0.22209529]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77789984 0.22210016]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.77789772 0.22210228]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02376156 0.97623844]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.39636657 0.60363343]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42387117 0.57612883]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42793925 0.57206075]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42858898 0.57141102]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42869399 0.57130601]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.428711 0.571289]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42871375 0.57128625]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95857011 0.04142989]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83581482 0.16418518]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.80954725 0.19045275]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.80159787 0.19840213]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79891508 0.20108492]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.7979753 0.2020247]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79764175 0.20235825]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79752281 0.20247719]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79748033 0.20251967]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79746515 0.20253485]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79745972 0.20254028]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.79745778 0.20254222]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02575784 0.97424216]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.41295106 0.58704894]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44309553 0.55690447]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44801125 0.55198875]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44888772 0.55111228]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44904642 0.55095358]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44907524 0.55092476]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44908047 0.55091953]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44908142 0.55091858]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.96173329 0.03826671]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84550892 0.15449108]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82241685 0.17758315]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81615719 0.18384281]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81430714 0.18569286]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8137461 0.1862539]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81357462 0.18642538]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81352209 0.18647791]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81350598 0.18649402]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81350104 0.18649896]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.81349953 0.18650047]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.02789828 0.97210172]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42917608 0.57082392]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46205927 0.53794073]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46796945 0.53203055]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.4691478 0.5308522]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46938746 0.53061254]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46943641 0.53056359]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46944641 0.53055359]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46944845 0.53055155]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.96464029 0.03535971]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85440129 0.14559871]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83399496 0.16600504]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8289912 0.1710088]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82767504 0.17232496]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82732237 0.17267763]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8272274 0.1727726]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82720179 0.17279821]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82719488 0.17280512]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82719302 0.17280698]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.82719252 0.17280748]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.03019908 0.96980092]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.44498395 0.55501605]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48069243 0.51930757]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48776499 0.51223501]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48934527 0.51065473]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48970764 0.51029236]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48979122 0.51020878]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48981053 0.51018947]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48981499 0.51018501]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.96732103 0.03267897]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86255283 0.13744717]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84442696 0.15557304]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84037388 0.15962612]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83941341 0.16058659]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83918264 0.16081736]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83912701 0.16087299]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83911359 0.16088641]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83911035 0.16088965]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.83910957 0.16089043]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.32700970368791904
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.08304427917230671
# Liquid comp: [0.45681933 0.54318067]
# Vapor comp: [0.85416155 0.14583845]
# K old: [1.86980168 0.26848977]
# K new: [1.74565155 0.30451183]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.02006509499530221
# Liquid comp: [0.48259593 0.51740407]
# Vapor comp: [0.84244434 0.15755566]
# K old: [1.74565155 0.30451183]
# K new: [1.7208628  0.31286545]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.005098708582915957
# Liquid comp: [0.48802261 0.51197739]
# Vapor comp: [0.83981996 0.16018004]
# K old: [1.7208628  0.31286545]
# K new: [1.7152751 0.3148369]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.0016209471756540557
# Liquid comp: [0.48924908 0.51075092]
# Vapor comp: [0.83919677 0.16080323]
# K old: [1.7152751 0.3148369]
# K new: [1.71398185 0.31530437]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.000817080197302512
# Liquid comp: [0.48953074 0.51046926]
# Vapor comp: [0.83904681 0.16095319]
# K old: [1.71398185 0.31530437]
# K new: [1.71368063 0.31541539]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.0006314987937721791
# Liquid comp: [0.48959567 0.51040433]
# Vapor comp: [0.83901062 0.16098938]
# K old: [1.71368063 0.31541539]
# K new: [1.71361035 0.31544177]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.0005886675067285472
# Liquid comp: [0.48961065 0.51038935]
# Vapor comp: [0.83900188 0.16099812]
# K old: [1.71361035 0.31544177]
# K new: [1.71359394 0.31544805]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.0005787829062144425
# Liquid comp: [0.48961411 0.51038589]
# Vapor comp: [0.83899977 0.16100023]
# K old: [1.71359394 0.31544805]
# K new: [1.7135901  0.31544954]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.0005765017748382841
# Liquid comp: [0.48961491 0.51038509]
# Vapor comp: [0.83899926 0.16100074]
# K old: [1.7135901  0.31544954]
# K new: [1.71358921 0.31544989]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.0005759753460180536
# Liquid comp: [0.48961509 0.51038491]
# Vapor comp: [0.83899913 0.16100087]
# Exit flag:1
# K old: [1.71358921 0.31544989]
# K new: [1.713589   0.31544998]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.0005758538594327603
# Liquid comp: [0.48961513 0.51038487]
# Vapor comp: [0.8389991 0.1610009]
# Exit flag:2
# K old: [1.713589   0.31544998]
# K new: [1.71358895 0.31545   ]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.48961513 0.51038487] [0.8389991 0.1610009]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.03267897 0.96732103]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.46029693 0.53970307]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.49889904 0.50110096]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.50732363 0.49267637]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.50943903 0.49056097]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.50998845 0.49001155]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.5101324 0.4898676]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.5101702 0.4898298]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.51018013 0.48981987]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.51018274 0.48981726]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.96980092 0.03019908]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8700083 0.1299917]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85382172 0.14617828]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85049788 0.14950212]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84978121 0.15021879]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84962505 0.15037495]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84959094 0.15040906]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84958349 0.15041651]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.84958186 0.15041814]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8495815 0.1504185]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.3586658664679799
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.13430323399752622
# Liquid comp: [0.45681933 0.54318067]
# Vapor comp: [0.85416155 0.14583845]
# K old: [1.86980168 0.26848977]
# K new: [1.74565155 0.30451183]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.07666489216892731
# Liquid comp: [0.48259593 0.51740407]
# Vapor comp: [0.84244434 0.15755566]
# K old: [1.74565155 0.30451183]
# K new: [1.7208628  0.31286545]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.06299382068140534
# Liquid comp: [0.48802261 0.51197739]
# Vapor comp: [0.83981996 0.16018004]
# K old: [1.7208628  0.31286545]
# K new: [1.7152751 0.3148369]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.0598220662127039
# Liquid comp: [0.48924908 0.51075092]
# Vapor comp: [0.83919677 0.16080323]
# K old: [1.7152751 0.3148369]
# K new: [1.71398185 0.31530437]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.05909007205946838
# Liquid comp: [0.48953074 0.51046926]
# Vapor comp: [0.83904681 0.16095319]
# K old: [1.71398185 0.31530437]
# K new: [1.71368063 0.31541539]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.05892135458607298
# Liquid comp: [0.48959567 0.51040433]
# Vapor comp: [0.83901062 0.16098938]
# K old: [1.71368063 0.31541539]
# K new: [1.71361035 0.31544177]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.058882480685674005
# Liquid comp: [0.48961065 0.51038935]
# Vapor comp: [0.83900188 0.16099812]
# K old: [1.71361035 0.31544177]
# K new: [1.71359394 0.31544805]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.058873525122086406
# Liquid comp: [0.48961411 0.51038589]
# Vapor comp: [0.83899977 0.16100023]
# K old: [1.71359394 0.31544805]
# K new: [1.7135901  0.31544954]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.058871462194497653
# Liquid comp: [0.48961491 0.51038509]
# Vapor comp: [0.83899926 0.16100074]
# K old: [1.7135901  0.31544954]
# K new: [1.71358921 0.31544989]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.05887098704062467
# Liquid comp: [0.48961509 0.51038491]
# Vapor comp: [0.83899913 0.16100087]
# Exit flag:1
# K old: [1.71358921 0.31544989]
# K new: [1.713589   0.31544998]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.0588708776089877
# Liquid comp: [0.48961513 0.51038487]
# Vapor comp: [0.8389991 0.1610009]
# Exit flag:2
# K old: [1.713589   0.31544998]
# K new: [1.71358895 0.31545   ]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.48961513 0.51038487] [0.8389991 0.1610009]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.03535971 0.96464029]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.47500709 0.52499291]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.5165435 0.4834565]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52652923 0.47347077]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52935589 0.47064411]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.5301923 0.4698077]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.53044303 0.46955697]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.53051848 0.46948152]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.53054121 0.46945879]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.53054806 0.46945194]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.53055013 0.46944987]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97210172 0.02789828]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87679492 0.12320508]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86225474 0.13774526]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8594951 0.1405049]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85894907 0.14105093]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85884014 0.14115986]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85881837 0.14118163]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85881402 0.14118598]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85881315 0.14118685]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.39032202924804077
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.18556218882274556
# Liquid comp: [0.45681933 0.54318067]
# Vapor comp: [0.85416155 0.14583845]
# K old: [1.86980168 0.26848977]
# K new: [1.74565155 0.30451183]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.13326468934255067
# Liquid comp: [0.48259593 0.51740407]
# Vapor comp: [0.84244434 0.15755566]
# K old: [1.74565155 0.30451183]
# K new: [1.7208628  0.31286545]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.12088893277989321
# Liquid comp: [0.48802261 0.51197739]
# Vapor comp: [0.83981996 0.16018004]
# K old: [1.7208628  0.31286545]
# K new: [1.7152751 0.3148369]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.11802318524975235
# Liquid comp: [0.48924908 0.51075092]
# Vapor comp: [0.83919677 0.16080323]
# K old: [1.7152751 0.3148369]
# K new: [1.71398185 0.31530437]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.1173630639216338
# Liquid comp: [0.48953074 0.51046926]
# Vapor comp: [0.83904681 0.16095319]
# K old: [1.71398185 0.31530437]
# K new: [1.71368063 0.31541539]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.11721121037837365
# Liquid comp: [0.48959567 0.51040433]
# Vapor comp: [0.83901062 0.16098938]
# K old: [1.71368063 0.31541539]
# K new: [1.71361035 0.31544177]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.11717629386461849
# Liquid comp: [0.48961065 0.51038935]
# Vapor comp: [0.83900188 0.16099812]
# K old: [1.71361035 0.31544177]
# K new: [1.71359394 0.31544805]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.11716826733795346
# Liquid comp: [0.48961411 0.51038589]
# Vapor comp: [0.83899977 0.16100023]
# K old: [1.71359394 0.31544805]
# K new: [1.7135901  0.31544954]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.11716642261415919
# Liquid comp: [0.48961491 0.51038509]
# Vapor comp: [0.83899926 0.16100074]
# K old: [1.7135901  0.31544954]
# K new: [1.71358921 0.31544989]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.11716599873523144
# Liquid comp: [0.48961509 0.51038491]
# Vapor comp: [0.83899913 0.16100087]
# Exit flag:1
# K old: [1.71358921 0.31544989]
# K new: [1.713589   0.31544998]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.11716590135854309
# Liquid comp: [0.48961513 0.51038487]
# Vapor comp: [0.8389991 0.1610009]
# Exit flag:2
# K old: [1.713589   0.31544998]
# K new: [1.71358895 0.31545   ]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.48961513 0.51038487] [0.8389991 0.1610009]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.03826671 0.96173329]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.48895908 0.51104092]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.53342726 0.46657274]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.54519361 0.45480639]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.54896031 0.45103969]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55023877 0.44976123]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55068131 0.44931869]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55083553 0.44916447]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.5508894 0.4491106]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55090824 0.44909176]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55091482 0.44908518]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55091713 0.44908287]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97424216 0.02575784]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.88291826 0.11708174]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86976659 0.13023341]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8674448 0.1325552]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86701987 0.13298013]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86694159 0.13305841]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86692715 0.13307285]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86692448 0.13307552]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86692399 0.13307601]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.42197819202810155
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.23682114364796472
# Liquid comp: [0.45681933 0.54318067]
# Vapor comp: [0.85416155 0.14583845]
# K old: [1.86980168 0.26848977]
# K new: [1.74565155 0.30451183]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.1898644865161759
# Liquid comp: [0.48259593 0.51740407]
# Vapor comp: [0.84244434 0.15755566]
# K old: [1.74565155 0.30451183]
# K new: [1.7208628  0.31286545]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.1787840448783828
# Liquid comp: [0.48802261 0.51197739]
# Vapor comp: [0.83981996 0.16018004]
# K old: [1.7208628  0.31286545]
# K new: [1.7152751 0.3148369]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.17622430428680153
# Liquid comp: [0.48924908 0.51075092]
# Vapor comp: [0.83919677 0.16080323]
# K old: [1.7152751 0.3148369]
# K new: [1.71398185 0.31530437]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.1756360557837993
# Liquid comp: [0.48953074 0.51046926]
# Vapor comp: [0.83904681 0.16095319]
# K old: [1.71398185 0.31530437]
# K new: [1.71368063 0.31541539]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.17550106617067462
# Liquid comp: [0.48959567 0.51040433]
# Vapor comp: [0.83901062 0.16098938]
# K old: [1.71368063 0.31541539]
# K new: [1.71361035 0.31544177]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.1754701070435627
# Liquid comp: [0.48961065 0.51038935]
# Vapor comp: [0.83900188 0.16099812]
# K old: [1.71361035 0.31544177]
# K new: [1.71359394 0.31544805]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.1754630095538202
# Liquid comp: [0.48961411 0.51038589]
# Vapor comp: [0.83899977 0.16100023]
# K old: [1.71359394 0.31544805]
# K new: [1.7135901  0.31544954]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.17546138303381958
# Liquid comp: [0.48961491 0.51038509]
# Vapor comp: [0.83899926 0.16100074]
# K old: [1.7135901  0.31544954]
# K new: [1.71358921 0.31544989]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.17546101042983733
# Liquid comp: [0.48961509 0.51038491]
# Vapor comp: [0.83899913 0.16100087]
# Exit flag:1
# K old: [1.71358921 0.31544989]
# K new: [1.713589   0.31544998]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.1754609251080975
# Liquid comp: [0.48961513 0.51038487]
# Vapor comp: [0.8389991 0.1610009]
# Exit flag:2
# K old: [1.713589   0.31544998]
# K new: [1.71358895 0.31545   ]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.48961513 0.51038487] [0.8389991 0.1610009]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.04142989 0.95857011]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.50191846 0.49808154]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.54924629 0.45075371]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.56299896 0.43700104]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.56798888 0.43201112]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.56994548 0.43005452]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57073615 0.42926385]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57105957 0.42894043]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57119252 0.42880748]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57124729 0.42875271]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57126987 0.42873013]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57127918 0.42872082]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57128302 0.42871698]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97623844 0.02376156]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.88835322 0.11164678]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87635436 0.12364564]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87437052 0.12562948]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87403197 0.12596803]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87397388 0.12602612]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.8739639 0.1260361]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87396219 0.12603781]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87396189 0.12603811]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.4536343548081625
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# ...
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 0.865164470948954
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 0.9544465112010352
# Liquid comp: [0.45681933 0.54318067]
# Vapor comp: [0.85416155 0.14583845]
# K old: [1.86980168 0.26848977]
# K new: [1.74565155 0.30451183]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 0.982261646946929
# Liquid comp: [0.48259593 0.51740407]
# Vapor comp: [0.84244434 0.15755566]
# K old: [1.74565155 0.30451183]
# K new: [1.7208628  0.31286545]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 0.9893156142572412
# Liquid comp: [0.48802261 0.51197739]
# Vapor comp: [0.83981996 0.16018004]
# K old: [1.7208628  0.31286545]
# K new: [1.7152751 0.3148369]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 0.9910399708054891
# Liquid comp: [0.48924908 0.51075092]
# Vapor comp: [0.83919677 0.16080323]
# K old: [1.7152751 0.3148369]
# K new: [1.71398185 0.31530437]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 0.9914579418541168
# Liquid comp: [0.48953074 0.51046926]
# Vapor comp: [0.83904681 0.16095319]
# K old: [1.71398185 0.31530437]
# K new: [1.71368063 0.31541539]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 0.9915590472628895
# Liquid comp: [0.48959567 0.51040433]
# Vapor comp: [0.83901062 0.16098938]
# K old: [1.71368063 0.31541539]
# K new: [1.71361035 0.31544177]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 0.9915834915487837
# Liquid comp: [0.48961065 0.51038935]
# Vapor comp: [0.83900188 0.16099812]
# K old: [1.71361035 0.31544177]
# K new: [1.71359394 0.31544805]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 0.9915894005759815
# Liquid comp: [0.48961411 0.51038589]
# Vapor comp: [0.83899977 0.16100023]
# K old: [1.71359394 0.31544805]
# K new: [1.7135901  0.31544954]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 0.9915908289090638
# Liquid comp: [0.48961491 0.51038509]
# Vapor comp: [0.83899926 0.16100074]
# K old: [1.7135901  0.31544954]
# K new: [1.71358921 0.31544989]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 0.9915911741543325
# Liquid comp: [0.48961509 0.51038491]
# Vapor comp: [0.83899913 0.16100087]
# Exit flag:1
# K old: [1.71358921 0.31544989]
# K new: [1.713589   0.31544998]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 0.9915912576018626
# Liquid comp: [0.48961513 0.51038487]
# Vapor comp: [0.8389991 0.1610009]
# Exit flag:2
# K old: [1.713589   0.31544998]
# K new: [1.71358895 0.31545   ]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.48961513 0.51038487] [0.8389991 0.1610009]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.16211151 0.83788849]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.47745937 0.52254063]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.51317509 0.48682491]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52173239 0.47826761]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52408996 0.47591004]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52476402 0.47523598]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52495877 0.47504123]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52501521 0.47498479]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52503158 0.47496842]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52503633 0.47496367]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.52503771 0.47496229]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.99459213 0.00540787]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87793303 0.12206697]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.86060462 0.13939538]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85727406 0.14272594]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85660119 0.14339881]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85646388 0.14353612]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85643579 0.14356421]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85643005 0.14356995]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.85642887 0.14357113]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.18753508 0.81246492]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.51498787 0.48501213]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.55793966 0.44206034]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57138138 0.42861862]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57660269 0.42339731]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57880303 0.42119697]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.57976245 0.42023755]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58018704 0.41981296]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58037618 0.41962382]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58046067 0.41953933]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58049847 0.41950153]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58051539 0.41948461]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58052297 0.41947703]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.58052636 0.41947364]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.99546313 0.00453687]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89262636 0.10737364]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87934453 0.12065547]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87721854 0.12278146]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87686634 0.12313366]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87680766 0.12319234]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87679788 0.12320212]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87679625 0.12320375]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.87679597 0.12320403]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.22055352 0.77944648]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.5602661 0.4397339]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.61402551 0.38597449]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.63935537 0.36064463]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.65846664 0.34153336]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.68064591 0.31935409]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.77109894 0.22890106]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.87291141 0.12708859]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.89375177 0.10624823]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.89670523 0.10329477]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.89710215 0.10289785]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.89715512 0.10284488]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.89716218 0.10283782]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.89716312 0.10283688]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.99629601 0.00370399]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.90821683 0.09178317]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89860318 0.10139682]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89735461 0.10264539]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89718876 0.10281124]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89716666 0.10283334]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89716372 0.10283628]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.89716333 0.10283667]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.26516765 0.73483235]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.6155541 0.3844459]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.68812299 0.31187701]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.84676117 0.15323883]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.90898238 0.09101762]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.9166352 0.0833648]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.91743824 0.08256176]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.9175211 0.0824789]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.91752963 0.08247037]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.91753051 0.08246949]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.9175306 0.0824694]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.99709322 0.00290678]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.92467091 0.07532909]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.91825585 0.08174415]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.91760519 0.08239481]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.91753829 0.08246171]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.9175314 0.0824686]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.91753069 0.08246931]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.32878696 0.67121304]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.68424999 0.31575001]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.87074821 0.12925179]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.93210583 0.06789417]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.93745825 0.06254175]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.93786491 0.06213509]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.93789548 0.06210452]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.93789777 0.06210223]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.93789795 0.06210205]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.997857 0.002143]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.94197283 0.05802717]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.93820176 0.06179824]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.93792076 0.06207924]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.93789967 0.06210033]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.93789809 0.06210191]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.93789797 0.06210203]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 3, Vap case: 3
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.42684213 0.57315787]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.77178583 0.22821417]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.9434982 0.0565018]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.95752118 0.04247882]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.95822872 0.04177128]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.95826351 0.04173649]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.95826522 0.04173478]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.9582653 0.0417347]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.9985894 0.0014106]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.96012065 0.03987935]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95835612 0.04164388]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95826977 0.04173023]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95826553 0.04173447]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.95826532 0.04173468]
# At P = 30 bar, and T = 500 K
# Run 2-phase flash.
# [3.30259579 0.10711737]
# SS Flash outer loop count: 0
# Vapor frac: 1.0551014476293192
# Liquid comp: [0.27942064 0.72057936]
# Vapor comp: [0.92281343 0.07718657]
# K old: [3.30259579 0.10711737]
# K new: [1.86980168 0.26848977]
# ########################################
# SS Flash outer loop count: 1
# Vapor frac: 1.2620002401523527
# Liquid comp: [0.45681933 0.54318067]
# Vapor comp: [0.85416155 0.14583845]
# K old: [1.86980168 0.26848977]
# K new: [1.74565155 0.30451183]
# ########################################
# SS Flash outer loop count: 2
# Vapor frac: 1.3218604299886796
# Liquid comp: [0.48259593 0.51740407]
# Vapor comp: [0.84244434 0.15755566]
# K old: [1.74565155 0.30451183]
# K new: [1.7208628  0.31286545]
# ########################################
# SS Flash outer loop count: 3
# Vapor frac: 1.33668628684818
# Liquid comp: [0.48802261 0.51197739]
# Vapor comp: [0.83981996 0.16018004]
# K old: [1.7208628  0.31286545]
# K new: [1.7152751 0.3148369]
# ########################################
# SS Flash outer loop count: 4
# Vapor frac: 1.340246685027783
# Liquid comp: [0.48924908 0.51075092]
# Vapor comp: [0.83919677 0.16080323]
# K old: [1.7152751 0.3148369]
# K new: [1.71398185 0.31530437]
# ########################################
# SS Flash outer loop count: 5
# Vapor frac: 1.3410958930271093
# Liquid comp: [0.48953074 0.51046926]
# Vapor comp: [0.83904681 0.16095319]
# K old: [1.71398185 0.31530437]
# K new: [1.71368063 0.31541539]
# ########################################
# SS Flash outer loop count: 6
# Vapor frac: 1.3412981820166952
# Liquid comp: [0.48959567 0.51040433]
# Vapor comp: [0.83901062 0.16098938]
# K old: [1.71368063 0.31541539]
# K new: [1.71361035 0.31544177]
# ########################################
# SS Flash outer loop count: 7
# Vapor frac: 1.3413463706224495
# Liquid comp: [0.48961065 0.51038935]
# Vapor comp: [0.83900188 0.16099812]
# K old: [1.71361035 0.31544177]
# K new: [1.71359394 0.31544805]
# ########################################
# SS Flash outer loop count: 8
# Vapor frac: 1.3413578538711912
# Liquid comp: [0.48961411 0.51038589]
# Vapor comp: [0.83899977 0.16100023]
# K old: [1.71359394 0.31544805]
# K new: [1.7135901  0.31544954]
# ########################################
# SS Flash outer loop count: 9
# Vapor frac: 1.3413605914270252
# Liquid comp: [0.48961491 0.51038509]
# Vapor comp: [0.83899926 0.16100074]
# K old: [1.7135901  0.31544954]
# K new: [1.71358921 0.31544989]
# ########################################
# SS Flash outer loop count: 10
# Vapor frac: 1.3413612443219711
# Liquid comp: [0.48961509 0.51038491]
# Vapor comp: [0.83899913 0.16100087]
# Exit flag:1
# K old: [1.71358921 0.31544989]
# K new: [1.713589   0.31544998]
# ########################################
# SS Flash outer loop count: 11
# Vapor frac: 1.3413614000991927
# Liquid comp: [0.48961513 0.51038487]
# Vapor comp: [0.8389991 0.1610009]
# Exit flag:2
# K old: [1.713589   0.31544998]
# K new: [1.71358895 0.31545   ]
# ########################################
# END 2-phase flash
# liq and vap comp:
# [0.48961513 0.51038487] [0.8389991 0.1610009]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.59766698 0.40233302]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.88946486 0.11053514]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.97604763 0.02395237]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.97856892 0.02143108]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.97863109 0.02136891]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.97863261 0.02136739]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.97863265 0.02136735]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [9.99292335e-01 7.07665373e-04]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97912373 0.02087627]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.9786447 0.0213553]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97863295 0.02136705]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97863266 0.02136734]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.97863265 0.02136735]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.97006155 0.02993845]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.99896589 0.00103411]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.99899996 0.00100004]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.999 0.001]
# EOS used in SA Liq. P = 30, T = 500, x_liq = [0.999 0.001]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [9.99967534e-01 3.24657098e-05]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [9.99001088e-01 9.98912350e-04]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.999 0.001]
# EOS used in SA Vap. P = 30, T = 500, x_liq = [0.999 0.001]
# At P = 30 bar, and T = 500 K
# Single phase stable
# P = 30 bar, T = 500 K
# Liq case: 2, Vap case: 2
# END

# %%
EOS_z = np.array(EOS_z)
EOS_vcomp = np.array(EOS_vcomp)

fig = plt.figure('''figsize=(20,20)''')
ax = fig.add_subplot(111)
ax.plot(EOS_z[:,0], EOS_vcomp[:,0])
ax.set_title(r'EOS $nC_4$ Vapor Composition vs Overall $nC_4$')
ax.set_xlabel(r'$z_{nC_4}$')
ax.set_ylabel(r'$y_{nC_4}$')
# Out:
# Text(0, 0.5, '$y_{nC_4}$')

# %% [markdown]
# EOS vs ANN comparison plot

# %%
fig = plt.figure('''figsize=(20,20)''')
ax = fig.add_subplot(111)
ax.plot(EOS_z[:,0], EOS_vcomp[:,0], label='EOS')
ax.plot(ANN_z[:,0], ANN_vcomp[:,0], label='ANN')
ax.set_title(r'EOS $nC_4$ Vapor Composition vs Overall $nC_4$')
ax.set_xlabel(r'$z_{nC_4}$')
ax.set_ylabel(r'$y_{nC_4}$')
ax.legend()

# %%
ANN_vcomp - EOS_vcomp
