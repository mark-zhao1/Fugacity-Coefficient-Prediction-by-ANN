# %% [markdown]
# Random simplex generator

# %%
import numpy as np
from numba import jit
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # For 3D Plot

# %%
# Set number of components
n = 3

# %%
arr = np.random.rand(n+1)

# %%
arr[0] = 0
arr[-1] = 1
arr
# Out:
# array([0.        , 0.49885676, 0.03159452, 1.        ])

# %%
diff = np.diff(arr)

# %%
diff
# Out:
# array([ 0.49885676, -0.46726224,  0.96840548])

# %%
np.sum(diff)
# Out:
# 1.0

# %%
def random_comp(n):
    arr = np.random.rand(n+1)
    arr[0] = 0
    arr[-1] = 1
    return np.diff(np.sort(arr))

# %%
# %timeit random_comp(3)
# Out:
# 11.2 µs ± 35.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
@jit(nopython=True)
def random_comp_nb(n):
    arr = np.random.rand(n+1)
    arr[0] = 0
    arr[-1] = 1
    return np.diff(np.sort(arr))

# %%
# %timeit random_comp_nb(3)
# Out:
# The slowest run took 9.83 times longer than the fastest. This could mean that an intermediate result is being cached.
# 5.8 µs ± 7.28 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
arr = np.empty((100,2))
for i in range(100):
    arr[i,:]= random_comp_nb(2)
plt.scatter(np.arange(100), np.sort(arr[:,1]))

# %%
plt.scatter(np.linspace(0,1,100), np.arange(100))

# %% [markdown]
# Now try with latin hypercube sampling
#
# LHS tends to cover the n-dimensional space more evenly than random sampling.

# %%
from pyDOE import *

# %%
temp = lhs(2, samples=10, criterion='m')
x = temp[:,0]
y = temp[:,1]
plt.scatter(x,y)

# %%
temp = []
for i in range(10):
    temp.append(np.random.rand(2))
temp = np.array(temp)
x = temp[:,0]
y = temp[:,1]
plt.scatter(x,y)

# %% [markdown]
# Here is a function which returns a random set of compositions using LHS. Must set the number of samples.

# %%
# Returns all samples at once (required)
def lhs_simplex(n_comps, n_samples):
    temp = lhs(n_comps-1, samples=n_samples, criterion='c')
    temp = np.sort(temp, axis=1)
    arr = np.empty((n_samples, n_comps+1))
    arr[:,0] = 0
    arr[:,-1] = 1
    arr[:, 1:-1] = temp
    return np.diff(np.sort(arr))

# %%
lhs_simplex(6, 10000)
# Out:
# array([[0.12885, 0.0817 , 0.0872 , 0.0785 , 0.3547 , 0.26905],
#        [0.17405, 0.3096 , 0.2937 , 0.0249 , 0.0225 , 0.17525],
#        [0.26145, 0.0014 , 0.0369 , 0.4279 , 0.1072 , 0.16515],
#        ...,
#        [0.07695, 0.0579 , 0.0064 , 0.0786 , 0.3043 , 0.47585],
#        [0.06055, 0.5095 , 0.0756 , 0.0552 , 0.0285 , 0.27065],
#        [0.04625, 0.0165 , 0.206  , 0.0505 , 0.1993 , 0.48145]])

# %% [markdown]
# Compare the distribution from LHS and random sampling for a 2 components. LHS samples evenly with the number of samples. Random can have large gaps.

# %%
temp = lhs_simplex(2,10)
x = temp[:,0]
y = temp[:,1]
plt.scatter(x,x)

# %%
n_comps = 2
n_samples = 10
arr = np.empty((n_samples,n_comps))
for i in range(n_samples):
    arr[i,:]= random_comp_nb(n_comps)
plt.scatter(arr[:,0], arr[:,0])
plt.xlim(0,1)
plt.ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# Compare LHS and random for 3 components
#
# LHS

# %%
# %matplotlib notebook
temp = lhs_simplex(3,30)
x = temp[:,0]
y = temp[:,1]
z = temp[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Random

# %%
n_comps = 3
n_samples = 30
arr = np.empty((n_samples,n_comps))
for i in range(n_samples):
    arr[i,:]= random_comp_nb(n_comps)
    
x = arr[:,0]
y = arr[:,1]
z = arr[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x,y,z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
XX = lhs_simplex(2, 4)

# %%
for i in XX:
    print(i)
# Out:
# [0.0110079 0.9889921]
# [0.33753957 0.66246043]
# [0.99400023 0.00599977]
# [0.68996491 0.31003509]

# %%
XX
# Out:
# array([[0.0110079 , 0.9889921 ],
#        [0.33753957, 0.66246043],
#        [0.99400023, 0.00599977],
#        [0.68996491, 0.31003509]])

# %%
# %time lhs_simplex(6, 10000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# <ipython-input-17-b7bd838331ff> in lhs_simplex(n_comps, n_samples)
#       1 # Returns all samples at once (required)
#       2 def lhs_simplex(n_comps, n_samples):
# ----> 3     temp = lhs(n_comps-1, samples=n_samples, criterion='m')
#       4     temp = np.sort(temp, axis=1)
#       5     arr = np.empty((n_samples, n_comps+1))
#
# ~\anaconda3\envs\gputest\lib\site-packages\pyDOE\doe_lhs.py in lhs(n, samples, criterion, iterations)
#     111             H = _lhscentered(n, samples)
#     112         elif criterion.lower() in ('maximin', 'm'):
# --> 113             H = _lhsmaximin(n, samples, iterations, 'maximin')
#     114         elif criterion.lower() in ('centermaximin', 'cm'):
#     115             H = _lhsmaximin(n, samples, iterations, 'centermaximin')
#
# ~\anaconda3\envs\gputest\lib\site-packages\pyDOE\doe_lhs.py in _lhsmaximin(n, samples, iterations, lhstype)
#     172             Hcandidate = _lhscentered(n, samples)
#     173
# --> 174         d = _pdist(Hcandidate)
#     175         if maxdist<np.min(d):
#     176             maxdist = np.min(d)
#
# ~\anaconda3\envs\gputest\lib\site-packages\pyDOE\doe_lhs.py in _pdist(x)
#     239     for i in range(m - 1):
#     240         for j in range(i + 1, m):
# --> 241             d.append((sum((x[j, :] - x[i, :])**2))**0.5)
#     242
#     243     return np.array(d)
#
# KeyboardInterrupt:
